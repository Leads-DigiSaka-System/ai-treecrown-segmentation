# %%
import os
import glob
import shutil
from pathlib import Path

# %%
def yolo_format(annotations_dir, output_dir=None):
    """
    Convert all YOLO segmentation classes to a single class "Tree-crown" (class index 0).
    Handles polygon segmentation format (class_id x1 y1 x2 y2 x3 y3 ...)

    Args:
        annotations_dir: Directory containing original YOLO label files (.txt)
        output_dir: Optional output directory. If None, overwrites original files.
    """

    # Create output directory if specified
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
        print(f"📁 Output directory: {output_dir}")
    else:
        print("⚠️  Warning: Will overwrite original files")

    # Process all annotation files
    annotation_files = glob.glob(os.path.join(annotations_dir, '*.txt'))

    if len(annotation_files) == 0:
        print(f"❌ No .txt files found in {annotations_dir}")
        return

    print(f"\n🔄 Processing {len(annotation_files)} annotation files...")
    print("="*70)

    total_polygons_converted = 0
    files_processed = 0
    bbox_format_count = 0
    polygon_format_count = 0

    for ann_file in annotation_files:
        try:
            # Read original annotations
            with open(ann_file, 'r') as f:
                lines = f.readlines()

            new_lines = []
            polygons_in_file = 0

            for line in lines:
                line = line.strip()

                # Skip empty lines
                if not line:
                    continue

                parts = line.split()

                # Determine format type
                if len(parts) == 5:
                    # Bounding box format: class_id x_center y_center width height
                    new_line = f"0 {' '.join(parts[1:])}\n"
                    bbox_format_count += 1
                elif len(parts) >= 7 and len(parts) % 2 == 1:
                    # Polygon segmentation format: class_id x1 y1 x2 y2 x3 y3 ...
                    # Must have odd number of elements (class + pairs of coordinates)
                    coordinates = ' '.join(parts[1:])
                    new_line = f"0 {coordinates}\n"
                    polygon_format_count += 1
                else:
                    print(f"⚠️  Skipping invalid line in {os.path.basename(ann_file)}")
                    print(f"    Line has {len(parts)} parts (expected 5 for bbox or odd number for polygon)")
                    continue

                new_lines.append(new_line)
                polygons_in_file += 1

            # Determine output file path
            if output_dir:
                output_file = os.path.join(output_dir, os.path.basename(ann_file))
            else:
                output_file = ann_file

            # Write converted annotations
            with open(output_file, 'w') as f:
                f.writelines(new_lines)

            total_polygons_converted += polygons_in_file
            files_processed += 1

            # Show sample of first file
            if files_processed == 1 and polygons_in_file > 0:
                num_coords = len(new_lines[0].split()) - 1
                print(f"📝 Detected format: {'Polygon Segmentation' if num_coords > 4 else 'Bounding Box'}")
                print(f"   First annotation has {num_coords} coordinate values ({num_coords//2} points)")
                print(f"   Sample: {new_lines[0][:80]}..." if len(new_lines[0]) > 80 else f"   Sample: {new_lines[0].strip()}")
                print()

            print(f"✓ {os.path.basename(ann_file)}: {polygons_in_file} annotations → Tree-crown (class 0)")

        except Exception as e:
            print(f"❌ Error processing {os.path.basename(ann_file)}: {e}")

    print("="*70)
    print(f"\n✅ Conversion Complete!")
    print(f"   Files processed: {files_processed}/{len(annotation_files)}")
    print(f"   Total annotations converted: {total_polygons_converted}")
    if bbox_format_count > 0:
        print(f"   - Bounding boxes: {bbox_format_count}")
    if polygon_format_count > 0:
        print(f"   - Polygon segmentations: {polygon_format_count}")
    print(f"   All classes are now: 0 (Tree-crown)")


def verify_conversion(directory, num_samples=5):
    """
    Verify the conversion by displaying sample annotations.

    Args:
        directory: Directory containing converted label files
        num_samples: Number of sample files to display
    """
    print(f"\n{'='*70}")
    print("VERIFICATION - Sample Annotations")
    print(f"{'='*70}")

    annotation_files = glob.glob(os.path.join(directory, '*.txt'))[:num_samples]

    for ann_file in annotation_files:
        print(f"\n📄 File: {os.path.basename(ann_file)}")
        print("-"*70)

        with open(ann_file, 'r') as f:
            lines = f.readlines()

        if lines:
            # Show first 3 annotations
            for i, line in enumerate(lines[:3], 1):
                parts = line.strip().split()
                num_coords = len(parts) - 1

                # Truncate long lines for display
                display_line = line.strip()
                if len(display_line) > 100:
                    display_line = display_line[:97] + "..."

                print(f"  Annotation {i}:")
                print(f"    Class: {parts[0]} (Tree-crown)")
                print(f"    Coordinates: {num_coords} values ({num_coords//2} points)")
                print(f"    Data: {display_line}")

            if len(lines) > 3:
                print(f"  ... ({len(lines) - 3} more annotations)")
        else:
            print("  (empty file)")


def analyze_labels(directory):
    """
    Analyze label files to show class distribution and format info.

    Args:
        directory: Directory containing label files
    """
    print(f"\n{'='*70}")
    print("LABEL ANALYSIS")
    print(f"{'='*70}")

    annotation_files = glob.glob(os.path.join(directory, '*.txt'))

    class_counts = {}
    total_annotations = 0
    total_points = []
    format_types = {'bbox': 0, 'polygon': 0}

    for ann_file in annotation_files:
        with open(ann_file, 'r') as f:
            for line in f:
                line = line.strip()
                if line:
                    parts = line.split()

                    if len(parts) >= 3:  # At minimum: class + 1 coordinate pair
                        class_id = parts[0]
                        num_coords = len(parts) - 1

                        class_counts[class_id] = class_counts.get(class_id, 0) + 1
                        total_annotations += 1
                        total_points.append(num_coords // 2)

                        # Determine format
                        if num_coords == 4:
                            format_types['bbox'] += 1
                        else:
                            format_types['polygon'] += 1

    print(f"\n📊 Class Distribution:")
    print("-"*70)
    for class_id, count in sorted(class_counts.items()):
        percentage = (count / total_annotations * 100) if total_annotations > 0 else 0
        print(f"  Class {class_id}: {count:,} annotations ({percentage:.2f}%)")

    print(f"\n📐 Format Information:")
    print("-"*70)
    if format_types['bbox'] > 0:
        print(f"  Bounding boxes: {format_types['bbox']:,}")
    if format_types['polygon'] > 0:
        print(f"  Polygon segmentations: {format_types['polygon']:,}")
        if total_points:
            avg_points = sum(total_points) / len(total_points)
            min_points = min(total_points)
            max_points = max(total_points)
            print(f"    - Average points per polygon: {avg_points:.1f}")
            print(f"    - Points range: {min_points} to {max_points}")

    print(f"\n  Total: {total_annotations:,} annotations in {len(annotation_files)} files")

# %%
if __name__ == "__main__":
    # Configuration
    annotations_dir = "/content/drive/MyDrive/AGRI/TreeCrown_Segmentation/dataset/valid/labels"
    output_dir = "/content/drive/MyDrive/AGRI/TreeCrown_Segmentation/dataset/valid/formatLabels"

    # Step 1: Analyze original labels
    print("\n🔍 STEP 1: Analyzing ORIGINAL labels...")
    analyze_labels(annotations_dir)

    # Step 2: Convert labels
    print("\n\n🔄 STEP 2: Converting labels...")
    yolo_format(annotations_dir, output_dir)

    # Step 3: Verify conversion
    print("\n\n🔍 STEP 3: Verifying conversion...")
    verify_conversion(output_dir, num_samples=3)

    # Step 4: Analyze converted labels
    print("\n\n📊 STEP 4: Analyzing CONVERTED labels...")
    analyze_labels(output_dir)

    print(f"\n{'='*70}")
    print("✅ ALL DONE!")
    print(f"{'='*70}")
    print(f"\nOriginal files: {annotations_dir}")
    print(f"Converted files: {output_dir}")
    print(f"\nAll classes have been converted to class 0 (Tree-crown)")
    print(f"{'='*70}\n")
# Out:
# 🔍 STEP 1: Analyzing ORIGINAL labels...
#
# ======================================================================
# LABEL ANALYSIS
# ======================================================================
#
# 📊 Class Distribution:
# ----------------------------------------------------------------------
#   Class 0: 1,334 annotations (41.26%)
#   Class 1: 318 annotations (9.84%)
#   Class 2: 1,581 annotations (48.90%)
#
# 📐 Format Information:
# ----------------------------------------------------------------------
#   Polygon segmentations: 3,233
#     - Average points per polygon: 45.0
#     - Points range: 4 to 140
#
#   Total: 3,233 annotations in 49 files
#
#
# 🔄 STEP 2: Converting labels...
# 📁 Output directory: /content/drive/MyDrive/AGRI/TreeCrown_Segmentation/dataset/valid/formatLabels
#
# 🔄 Processing 49 annotation files...
# ======================================================================
# 📝 Detected format: Polygon Segmentation
#    First annotation has 78 coordinate values (39 points)
#    Sample: 0 0.44375 0.8234375 0.4421875 0.825 0.4421875 0.8375 0.44375 0.8390625 0.44375 0...
#
# ✓ 52000_20000_2773_1031_jpg.rf.eabce235b72bd9ad360f86afeeab1a0d.txt: 71 annotations → Tree-crown (class 0)
# ✓ img-112-_jpg.rf.bc109f7ec9b15c223665f23a1b96ab23.txt: 40 annotations → Tree-crown (class 0)
# ✓ 52000_20000_3906_1960_jpg.rf.e641ecebe062d8e77522134298b85e75.txt: 76 annotations → Tree-crown (class 0)
# ✓ img-131-_jpg.rf.c1ce29d422d24484860d010968e200d3.txt: 39 annotations → Tree-crown (class 0)
# ✓ img-97-_jpg.rf.5f70a1417aa479bba184cefdfa7367db.txt: 115 annotations → Tree-crown (class 0)
# ✓ img-79-_jpg.rf.83625c5418f952bc928f768bfc047de7.txt: 45 annotations → Tree-crown (class 0)
# ✓ 52000_20000_2922_1323_jpg.rf.364e44f02fdcb9e42bda0ac542cde7c6.txt: 76 annotations → Tree-crown (class 0)
# ✓ 44000_4000_988_2749_jpg.rf.4c81b4a029c0ca485b5d1b6665a9d067.txt: 73 annotations → Tree-crown (class 0)
# ✓ img-104-_jpg.rf.c59d75f14ba7e5f13b8584f7e5196974.txt: 147 annotations → Tree-crown (class 0)
# ✓ 52000_20000_1528_1667_jpg.rf.5668de7e123240b63e644ba6d28ad004.txt: 74 annotations → Tree-crown (class 0)
# ✓ img-82-_jpg.rf.1d92a7ab6a81514c3a5b26a13a426312.txt: 43 annotations → Tree-crown (class 0)
# ✓ 44000_4000_1530_2780_jpg.rf.594dc21b8975e05a1ea73c682d7fb646.txt: 60 annotations → Tree-crown (class 0)
# ✓ 52000_20000_2382_2058_jpg.rf.8f244ffebb684915eb1ee88ba02421ea.txt: 52 annotations → Tree-crown (class 0)
# ✓ img-110-_jpg.rf.e2716cea78b6cf11c5fe25475270f65c.txt: 53 annotations → Tree-crown (class 0)
# ✓ img-112-_jpg.rf.8fdbe20e8c2642afa273b4c59a1459f0.txt: 40 annotations → Tree-crown (class 0)
# ✓ img-67-_jpg.rf.2a9d10011424338a68b7f7397f74f581.txt: 52 annotations → Tree-crown (class 0)
# ✓ img-93-_jpg.rf.c7945708ee624e168734abd53bf5d66b.txt: 30 annotations → Tree-crown (class 0)
# ✓ img-81-_jpg.rf.4d0d0c47d5c9052b39de356f2b8e003e.txt: 45 annotations → Tree-crown (class 0)
# ✓ img-131-_jpg.rf.dc04461c3e97601095c931d63de5e239.txt: 39 annotations → Tree-crown (class 0)
# ✓ 44000_4000_2788_2208_jpg.rf.738fe32388bc6e6d5fef21212661c9a5.txt: 61 annotations → Tree-crown (class 0)
# ✓ 44000_4000_2672_2826_jpg.rf.80d106337b971aa4bb37eb2ddd2ae09e.txt: 66 annotations → Tree-crown (class 0)
# ✓ img-82-_jpg.rf.1472212784956b2c922b3772f373ef90.txt: 43 annotations → Tree-crown (class 0)
# ✓ 52000_20000_708_878_jpg.rf.8df7757cab9297552a3a5bc9a41ddfee.txt: 72 annotations → Tree-crown (class 0)
# ✓ 44000_16000_764_2638_jpg.rf.27d7a16607cd6be132bcb25ba9859551.txt: 64 annotations → Tree-crown (class 0)
# ✓ 44000_16000_243_3488_jpg.rf.6d62946b5665bc476e17832755eea0ad.txt: 68 annotations → Tree-crown (class 0)
# ✓ img-19-_jpg.rf.4062c2c62b1b89e54f91dc4ec16ab4d8.txt: 127 annotations → Tree-crown (class 0)
# ✓ 44000_4000_2672_1380_jpg.rf.70769a6d3a6b7d9e1f2a7a7aeac9a0f7.txt: 59 annotations → Tree-crown (class 0)
# ✓ 44000_4000_2570_2038_jpg.rf.f36e1675b37d1e9c8641e2ff3e3d26fd.txt: 51 annotations → Tree-crown (class 0)
# ✓ img-104-_jpg.rf.8c5a27c99669bd3add92a3a8f2b8547f.txt: 147 annotations → Tree-crown (class 0)
# ✓ 44000_16000_2112_1601_jpg.rf.2ff856ca1719c1f86b1a6bb0d32d1994.txt: 74 annotations → Tree-crown (class 0)
# ✓ img-79-_jpg.rf.65a07d50f5a8f082e5ddba49a0f6e44b.txt: 45 annotations → Tree-crown (class 0)
# ✓ img-11-_jpg.rf.1211302c1daf9a7de8edb40722b64ce6.txt: 117 annotations → Tree-crown (class 0)
# ✓ img-67-_jpg.rf.c621895bc96072ef86030edfe7c5ec8e.txt: 52 annotations → Tree-crown (class 0)
# ✓ img-93-_jpg.rf.f96ca1ddbdb2e1b1c8df359173929aec.txt: 30 annotations → Tree-crown (class 0)
# ✓ 44000_16000_437_2102_jpg.rf.63a9d6d285678a1e42a50eb2f9e1dd3a.txt: 79 annotations → Tree-crown (class 0)
# ✓ 44000_16000_259_3839_jpg.rf.129a17672164ef1f44240eed92d992ec.txt: 68 annotations → Tree-crown (class 0)
# ✓ 44000_16000_2564_1817_jpg.rf.75edd3789063064a1222da9a29fdd1b3.txt: 84 annotations → Tree-crown (class 0)
# ✓ img-184-_jpg.rf.7de066508781e3abe3dff93c00c66a1d.txt: 44 annotations → Tree-crown (class 0)
# ✓ 44000_4000_832_2907_jpg.rf.829ec15d9c89d2886bca61fcf29a530d.txt: 68 annotations → Tree-crown (class 0)
# ✓ img-59-_jpg.rf.dcd7640729c042712962cf1ffbacbb6e.txt: 49 annotations → Tree-crown (class 0)
# ✓ img-81-_jpg.rf.7d7578f8fc80dc5d40188c233cdaf37d.txt: 45 annotations → Tree-crown (class 0)
# ✓ img-11-_jpg.rf.df9ed3c300338a049cf1c186caf7461d.txt: 116 annotations → Tree-crown (class 0)
# ✓ img-28-_jpg.rf.b0ea21f4dc55226147cf1b64b6420a9b.txt: 50 annotations → Tree-crown (class 0)
# ✓ img-28-_jpg.rf.7b4290d9668a7b6f272de0aa869f12fb.txt: 50 annotations → Tree-crown (class 0)
# ✓ 44000_16000_732_3260_jpg.rf.0133ba9391ce159281273357b549158c.txt: 69 annotations → Tree-crown (class 0)
# ✓ 44000_16000_1065_1216_jpg.rf.70cbabd00c19cee94decaf721435d8af.txt: 73 annotations → Tree-crown (class 0)
# ✓ 52000_20000_291_1764_jpg.rf.56f64e7cdf527413e41adc97f4aaddb8.txt: 68 annotations → Tree-crown (class 0)
# ✓ 44000_4000_3708_1648_jpg.rf.47e6a2653daf0ba87bcf9352a4e8c101.txt: 75 annotations → Tree-crown (class 0)
# ✓ img-89-_jpg.rf.ed70b888a12c8cb57202a175313d5453.txt: 49 annotations → Tree-crown (class 0)
# ======================================================================
#
# ✅ Conversion Complete!
#    Files processed: 49/49
#    Total annotations converted: 3233
#    - Polygon segmentations: 3233
#    All classes are now: 0 (Tree-crown)
#
#
# 🔍 STEP 3: Verifying conversion...
#
# ======================================================================
# VERIFICATION - Sample Annotations
# ======================================================================
#
# 📄 File: 52000_20000_2773_1031_jpg.rf.eabce235b72bd9ad360f86afeeab1a0d.txt
# ----------------------------------------------------------------------
#   Annotation 1:
#     Class: 0 (Tree-crown)
#     Coordinates: 78 values (39 points)
#     Data: 0 0.44375 0.8234375 0.4421875 0.825 0.4421875 0.8375 0.44375 0.8390625 0.44375 0.84375 0.4453125 ...
#   Annotation 2:
#     Class: 0 (Tree-crown)
#     Coordinates: 110 values (55 points)
#     Data: 0 0.2859375 0.8390625 0.28125 0.8390625 0.2796875 0.840625 0.278125 0.840625 0.275 0.84375 0.275 ...
#   Annotation 3:
#     Class: 0 (Tree-crown)
#     Coordinates: 114 values (57 points)
#     Data: 0 0.1671875 0.7796875 0.165625 0.78125 0.165625 0.784375 0.1640625 0.7859375 0.1640625 0.790625 0...
#   ... (68 more annotations)
#
# 📄 File: img-112-_jpg.rf.bc109f7ec9b15c223665f23a1b96ab23.txt
# ----------------------------------------------------------------------
#   Annotation 1:
#     Class: 0 (Tree-crown)
#     Coordinates: 22 values (11 points)
#     Data: 0 0.4224765625 0.17440781249999998 0.45222187500000005 0.158690625 0.45222187500000005 0.15280937...
#   Annotation 2:
#     Class: 0 (Tree-crown)
#     Coordinates: 20 values (10 points)
#     Data: 0 0.29159687500000003 0.1408609375 0.2906046875 0.12629375 0.260859375 0.13613124999999998 0.2440...
#   Annotation 3:
#     Class: 0 (Tree-crown)
#     Coordinates: 20 values (10 points)
#     Data: 0 0.14683437500000002 0.1228828125 0.13989374999999998 0.1169453125 0.108165625 0.1250875 0.10717...
#   ... (37 more annotations)
#
# 📄 File: 52000_20000_3906_1960_jpg.rf.e641ecebe062d8e77522134298b85e75.txt
# ----------------------------------------------------------------------
#   Annotation 1:
#     Class: 0 (Tree-crown)
#     Coordinates: 196 values (98 points)
#     Data: 0 0.1125 0.459375 0.1125 0.4625 0.1109375 0.4640625 0.109375 0.4640625 0.1078125 0.4625 0.10625 0...
#   Annotation 2:
#     Class: 0 (Tree-crown)
#     Coordinates: 178 values (89 points)
#     Data: 0 0.675 0.0125 0.6734375 0.0140625 0.671875 0.0140625 0.6703125 0.015625 0.66875 0.015625 0.66406...
#   Annotation 3:
#     Class: 0 (Tree-crown)
#     Coordinates: 214 values (107 points)
#     Data: 0 0.7671875 0.0609375 0.765625 0.0625 0.7640625 0.0625 0.7625 0.0640625 0.7609375 0.0640625 0.759...
#   ... (73 more annotations)
#
#
# 📊 STEP 4: Analyzing CONVERTED labels...
#
# ======================================================================
# LABEL ANALYSIS
# ======================================================================
#
# 📊 Class Distribution:
# ----------------------------------------------------------------------
#   Class 0: 3,233 annotations (100.00%)
#
# 📐 Format Information:
# ----------------------------------------------------------------------
#   Polygon segmentations: 3,233
#     - Average points per polygon: 45.0
#     - Points range: 4 to 140
#
#   Total: 3,233 annotations in 49 files
#
# ======================================================================
# ✅ ALL DONE!
# ======================================================================
#
# Original files: /content/drive/MyDrive/AGRI/TreeCrown_Segmentation/dataset/valid/labels
# Converted files: /content/drive/MyDrive/AGRI/TreeCrown_Segmentation/dataset/valid/formatLabels
#
# All classes have been converted to class 0 (Tree-crown)
# ======================================================================
